# %%
import pandas as pd

road = r"C:\2026_dissertation\ete_project\save_file\MLP\predictions.csv"
data = pd.read_csv(road)
data
# Out:
#              Date    Code    y_pred
# 0        20211214       1 -0.005766
# 1        20211214       2  0.000020
# 2        20211214       4  0.037019
# 3        20211214       6  0.036069
# 4        20211214       8 -0.011906
# ...           ...     ...       ...
# 5006237  20260320  688816  0.025265
# 5006238  20260320  688818 -0.012086
# 5006239  20260320  688819 -0.015075
# 5006240  20260320  688981  0.021603
# 5006241  20260320  689009 -0.018746
#
# [5006242 rows x 3 columns]
